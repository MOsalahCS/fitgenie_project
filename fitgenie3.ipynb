# %%
import pandas as pd

# %%
data = pd.read_csv('user_data_new4.csv')

data
# Out:
#       Unnamed: 0.1  Unnamed: 0  Age  Weight (kg)  Height (cm)  Gender  \
# 0                0           0   53    89.467865   178.728010  Female
# 1                1           1   49    73.084141   171.361333    Male
# 2                2           2   45    76.278518   154.100840    Male
# 3                3           3   21    66.727252   154.836663    Male
# 4                4           4   57    46.012487   154.926077  Female
# ...            ...         ...  ...          ...          ...     ...
# 9995          9995        9995   60    71.309278   161.509795    Male
# 9996          9996        9996   22    85.986722   191.083745    Male
# 9997          9997        9997   29    71.408203   191.461285    Male
# 9998          9998        9998   40    95.960986   144.518508  Female
# 9999          9999        9999   42    69.100194   161.822956    Male
#
#             BMI          BMR   Allergies  activity_level      Fitness Goals  \
# ...

# %%
data = data.drop(['Unnamed: 0.1','Unnamed: 0'],axis=1)

data
# Out:
#       Age  Weight (kg)  Height (cm)  Gender        BMI          BMR  \
# 0      53    89.467865   178.728010  Female  28.007983  1599.111724
# 1      49    73.084141   171.361333    Male  24.888429  1611.660274
# 2      45    76.278518   154.100840    Male  32.121235  1594.330244
# 3      21    66.727252   154.836663    Male  27.832719  1606.151136
# 4      57    46.012487   154.926077  Female  19.170201  1106.221450
# ...   ...          ...          ...     ...        ...          ...
# 9995   60    71.309278   161.509795    Male  27.336840  1478.157906
# 9996   22    85.986722   191.083745    Male  23.549620  2032.443010
# 9997   29    71.408203   191.461285    Male  19.479875  1799.207406
# 9998   40    95.960986   144.518508  Female  45.946005  1609.462573
# 9999   42    69.100194   161.822956    Male  26.387546  1552.251670
#
#        Allergies  activity_level      Fitness Goals  calories_intake_per_day  \
# ...

# %%
cat_feat = ["Gender","Allergies","Fitness Goals","Work Out Level"]
cont_feat = [x for x in data.columns.tolist() if x not in cat_feat]

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %%
cat_data_org=data[cat_feat]

# %%
cat_data_org
# Out:
#       Gender   Allergies      Fitness Goals Work Out Level
# 0     Female  No Allergy        Lose Weight       Beginner
# 1       Male  No Allergy  Healthy Lifestyle   Intermediate
# 2       Male   Shellfish        Lose Weight       Advanced
# 3       Male  No Allergy        Lose Weight       Beginner
# 4     Female   Shellfish  Healthy Lifestyle       Beginner
# ...      ...         ...                ...            ...
# 9995    Male         Egg        Lose Weight       Advanced
# 9996    Male       Dairy  Healthy Lifestyle       Advanced
# 9997    Male     Peanuts  Healthy Lifestyle       Beginner
# 9998  Female   Shellfish        Lose Weight       Advanced
# 9999    Male       Dairy        Lose Weight       Advanced
#
# [10000 rows x 4 columns]

# %%
cat_data = cat_data_org.copy()

# %%
labels_encoder = {}

# Iterate through each column and encode categorical values
for column in cat_feat:
    label_encoder = LabelEncoder()
    label_encoder.fit(cat_data_org[column])
    cat_data[column] = label_encoder.transform(cat_data_org[column])
    labels_encoder[column] = label_encoder

# %%
labels_encoder
# Out:
# {'Gender': LabelEncoder(),
#  'Allergies': LabelEncoder(),
#  'Fitness Goals': LabelEncoder(),
#  'Work Out Level': LabelEncoder()}

# %%
cat_data
# Out:
#       Gender  Allergies  Fitness Goals  Work Out Level
# 0          0          3              1               1
# 1          1          3              0               2
# 2          1          5              1               0
# 3          1          3              1               1
# 4          0          5              0               1
# ...      ...        ...            ...             ...
# 9995       1          1              1               0
# 9996       1          0              0               0
# 9997       1          4              0               1
# 9998       0          5              1               0
# 9999       1          0              1               0
#
# [10000 rows x 4 columns]

# %%
scaler = StandardScaler()
cont_data=scaler.fit_transform(data[cont_feat])

# %%
cont_data = pd.DataFrame(cont_data,columns=cont_feat)

# %%
cont_data
# Out:
#            Age  Weight (kg)  Height (cm)       BMI       BMR  activity_level  \
# 0     1.120175     1.071857     0.496693  0.271498  0.145338        0.290792
# 1     0.797565     0.035343     0.072243 -0.125030  0.201074        0.290792
# 2     0.474955     0.237435    -0.922265  0.794334  0.124100        1.455049
# 3    -1.460706    -0.366824    -0.879869  0.249220  0.176604        1.455049
# 4     1.442785    -1.677340    -0.874717 -0.851875 -2.043924        0.290792
# ...        ...          ...          ...       ...       ...             ...
# 9995  1.684742    -0.076943    -0.495379  0.186189 -0.391901        1.455049
# 9996 -1.380053     0.851623     1.208601 -0.295206  2.070057        1.455049
# 9997 -0.815486    -0.070685     1.230354 -0.812513  1.034099        1.455049
# 9998  0.071692     1.482643    -1.474376  2.551605  0.191313       -0.485379
# 9999  0.232997    -0.216700    -0.477335  0.065524 -0.062800       -1.261550
#
# ...

# %%
data_prep=pd.concat([cont_data,cat_data],axis=1)

# %%
data_prep
# Out:
#            Age  Weight (kg)  Height (cm)       BMI       BMR  activity_level  \
# 0     1.120175     1.071857     0.496693  0.271498  0.145338        0.290792
# 1     0.797565     0.035343     0.072243 -0.125030  0.201074        0.290792
# 2     0.474955     0.237435    -0.922265  0.794334  0.124100        1.455049
# 3    -1.460706    -0.366824    -0.879869  0.249220  0.176604        1.455049
# 4     1.442785    -1.677340    -0.874717 -0.851875 -2.043924        0.290792
# ...        ...          ...          ...       ...       ...             ...
# 9995  1.684742    -0.076943    -0.495379  0.186189 -0.391901        1.455049
# 9996 -1.380053     0.851623     1.208601 -0.295206  2.070057        1.455049
# 9997 -0.815486    -0.070685     1.230354 -0.812513  1.034099        1.455049
# 9998  0.071692     1.482643    -1.474376  2.551605  0.191313       -0.485379
# 9999  0.232997    -0.216700    -0.477335  0.065524 -0.062800       -1.261550
#
# ...

# %%
from kmodes.kprototypes import KPrototypes

# %%
test_model = KPrototypes(n_clusters=20, init='Huang', random_state=42)
test_model.fit_predict(data_prep, categorical=[9,10,11,12])
# Out:
# array([13,  4, 18, ...,  5,  0, 11], dtype=uint16)

# %%
clusters = test_model.predict(data_prep, categorical=[9,10,11,12])

# %%
clusters
# Out:
# array([13,  4, 18, ...,  5,  0, 11], dtype=uint16)

# %%
data_prep["clusters"]=clusters

# %%
data_prep
# Out:
#            Age  Weight (kg)  Height (cm)       BMI       BMR  activity_level  \
# 0     1.120175     1.071857     0.496693  0.271498  0.145338        0.290792
# 1     0.797565     0.035343     0.072243 -0.125030  0.201074        0.290792
# 2     0.474955     0.237435    -0.922265  0.794334  0.124100        1.455049
# 3    -1.460706    -0.366824    -0.879869  0.249220  0.176604        1.455049
# 4     1.442785    -1.677340    -0.874717 -0.851875 -2.043924        0.290792
# ...        ...          ...          ...       ...       ...             ...
# 9995  1.684742    -0.076943    -0.495379  0.186189 -0.391901        1.455049
# 9996 -1.380053     0.851623     1.208601 -0.295206  2.070057        1.455049
# 9997 -0.815486    -0.070685     1.230354 -0.812513  1.034099        1.455049
# 9998  0.071692     1.482643    -1.474376  2.551605  0.191313       -0.485379
# 9999  0.232997    -0.216700    -0.477335  0.065524 -0.062800       -1.261550
#
# ...

# %%
from sklearn.manifold import TSNE 
import plotly.express as px
import plotly.graph_objects as go

# %%
def plot_pca_2d(df, title = "PCA Space", opacity=0.8, width_line = 0.1):

    df = df.astype({"cluster": "object"})
    df = df.sort_values("cluster")


    fig = px.scatter(
          df, 
          x='comp1', 
          y='comp2', 
          color='cluster',
          
          # symbol = "cluster",
          
          color_discrete_sequence=px.colors.qualitative.Vivid,
          title=title).update_traces(
              # mode = 'markers',
              marker={
                  "size": 3,
                  "opacity": opacity,
                  # "symbol" : "diamond",
                  "line": {
                      "width": width_line,
                      "color": "black",
                  }
              }
          ).update_layout(
                  width = 800, 
                  height = 800, 
                  autosize = True, 
                  showlegend = True,
                  legend=dict(title_font_family="Times New Roman",
                              font=dict(size= 20)),
                  scene = dict(xaxis=dict(title = 'comp1', titlefont_color = 'black'),
                              yaxis=dict(title = 'comp2', titlefont_color = 'black')),
                              
                  font = dict(family = "Gilroy", color  = 'black', size = 20))
        
    
    fig.show()

# %%
sampling_data = data_prep.sample(frac=0.1, replace=True, random_state=1)

sampling_data = data_prep.copy()


df_tsne_2d = TSNE(
                  n_components=2, 
                   
                  init='pca',  
                  n_iter = 850).fit_transform(sampling_data)

df_tsne_2d = pd.DataFrame(df_tsne_2d, columns=["comp1", "comp2"])
df_tsne_2d["cluster"] = data_prep["clusters"]
plot_pca_2d(df_tsne_2d, title = "t-sne Space")
# Out:
# C:\Users\MOHAMED__SALH\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#
# C:\Users\MOHAMED__SALH\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning:
#
# The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.

# %%
data_prep
# Out:
#            Age  Weight (kg)  Height (cm)       BMI       BMR  activity_level  \
# 0     1.120175     1.071857     0.496693  0.271498  0.145338        0.290792
# 1     0.797565     0.035343     0.072243 -0.125030  0.201074        0.290792
# 2     0.474955     0.237435    -0.922265  0.794334  0.124100        1.455049
# 3    -1.460706    -0.366824    -0.879869  0.249220  0.176604        1.455049
# 4     1.442785    -1.677340    -0.874717 -0.851875 -2.043924        0.290792
# ...        ...          ...          ...       ...       ...             ...
# 9995  1.684742    -0.076943    -0.495379  0.186189 -0.391901        1.455049
# 9996 -1.380053     0.851623     1.208601 -0.295206  2.070057        1.455049
# 9997 -0.815486    -0.070685     1.230354 -0.812513  1.034099        1.455049
# 9998  0.071692     1.482643    -1.474376  2.551605  0.191313       -0.485379
# 9999  0.232997    -0.216700    -0.477335  0.065524 -0.062800       -1.261550
#
# ...

# %%
data_prep["Fitness Goals"].value_counts().sort_values(ascending=False).index[0]
# Out:
# 1

# %%
cat_agg={col: lambda x: x.value_counts().sort_values(ascending=False).index[0] for col in cat_feat}
cat_agg
# Out:
# {'Gender': <function __main__.<dictcomp>.<lambda>(x)>,
#  'Allergies': <function __main__.<dictcomp>.<lambda>(x)>,
#  'Fitness Goals': <function __main__.<dictcomp>.<lambda>(x)>,
#  'Work Out Level': <function __main__.<dictcomp>.<lambda>(x)>}

# %%
cont_agg={col: 'mean' for col in cont_feat}
cont_agg
# Out:
# {'Age': 'mean',
#  'Weight (kg)': 'mean',
#  'Height (cm)': 'mean',
#  'BMI': 'mean',
#  'BMR': 'mean',
#  'activity_level': 'mean',
#  'calories_intake_per_day': 'mean',
#  'carbs_intake_per_day': 'mean',
#  'protein_intake_per_day': 'mean'}

# %%
all_agg = {**cat_agg , **cont_agg}
all_agg
# Out:
# {'Gender': <function __main__.<dictcomp>.<lambda>(x)>,
#  'Allergies': <function __main__.<dictcomp>.<lambda>(x)>,
#  'Fitness Goals': <function __main__.<dictcomp>.<lambda>(x)>,
#  'Work Out Level': <function __main__.<dictcomp>.<lambda>(x)>,
#  'Age': 'mean',
#  'Weight (kg)': 'mean',
#  'Height (cm)': 'mean',
#  'BMI': 'mean',
#  'BMR': 'mean',
#  'activity_level': 'mean',
#  'calories_intake_per_day': 'mean',
#  'carbs_intake_per_day': 'mean',
#  'protein_intake_per_day': 'mean'}

# %%
cls_agg=data_prep.groupby('clusters').agg(
    all_agg
).reset_index()

# %%
cls_agg
# Out:
#     clusters  Gender  Allergies  Fitness Goals  Work Out Level       Age  \
# 0          0       1          2              1               1 -0.414468
# 1          1       1          0              0               1 -0.245929
# 2          2       0          4              1               1 -0.909528
# 3          3       0          5              2               2  0.950454
# 4          4       0          1              0               1  0.878582
# 5          5       1          2              0               1 -0.472526
# 6          6       1          5              0               2 -0.946326
# 7          7       0          5              0               2  0.636849
# 8          8       0          3              0               0  0.720745
# 9          9       0          5              1               0  0.725686
# 10        10       1          3              1               1 -0.504480
# 11        11       0          3              1               0  0.867619
# ...

# %%
cls_agg_decoded = cls_agg.copy()

# %%
for col in cls_agg[cat_feat].columns:
    
    cls_agg_decoded[col]=labels_encoder[col].inverse_transform(cls_agg[col])

# %%
cls_agg_decoded
# Out:
#     clusters  Gender   Allergies      Fitness Goals Work Out Level       Age  \
# 0          0    Male      Gluten        Lose Weight       Beginner -0.414468
# 1          1    Male       Dairy  Healthy Lifestyle       Beginner -0.245929
# 2          2  Female     Peanuts        Lose Weight       Beginner -0.909528
# 3          3  Female   Shellfish        Muscle Gain   Intermediate  0.950454
# 4          4  Female         Egg  Healthy Lifestyle       Beginner  0.878582
# 5          5    Male      Gluten  Healthy Lifestyle       Beginner -0.472526
# 6          6    Male   Shellfish  Healthy Lifestyle   Intermediate -0.946326
# 7          7  Female   Shellfish  Healthy Lifestyle   Intermediate  0.636849
# 8          8  Female  No Allergy  Healthy Lifestyle       Advanced  0.720745
# 9          9  Female   Shellfish        Lose Weight       Advanced  0.725686
# 10        10    Male  No Allergy        Lose Weight       Beginner -0.504480
# ...

# %%
cls_agg_decoded[cont_feat]=scaler.inverse_transform(cls_agg[cont_feat])

# %%
cls_agg_decoded
# Out:
#     clusters  Gender   Allergies      Fitness Goals Work Out Level        Age  \
# 0          0    Male      Gluten        Lose Weight       Beginner  33.972167
# 1          1    Male       Dairy  Healthy Lifestyle       Beginner  36.061856
# 2          2  Female     Peanuts        Lose Weight       Beginner  27.833984
# 3          3  Female   Shellfish        Muscle Gain   Intermediate  50.895652
# 4          4  Female         Egg  Healthy Lifestyle       Beginner  50.004525
# 5          5    Male      Gluten  Healthy Lifestyle       Beginner  33.252308
# 6          6    Male   Shellfish  Healthy Lifestyle   Intermediate  27.377734
# 7          7  Female   Shellfish  Healthy Lifestyle   Intermediate  47.007310
# 8          8  Female  No Allergy  Healthy Lifestyle       Advanced  48.047525
# 9          9  Female   Shellfish        Lose Weight       Advanced  48.108787
# 10        10    Male  No Allergy        Lose Weight       Beginner  32.856115
# ...

# %%
res = []
for column in data_prep[cat_feat+['clusters']].columns.difference(['clusters']):
    # Group by 'Cluster' column and count occurrences of each value in the current column
    result = data_prep[cat_feat+['clusters']].groupby('clusters')[column].value_counts().unstack(fill_value=0)
    result.columns = [column+" "+str(x) for x in result.columns.tolist() ]
    res.append(result)

# %%
pd.concat(res,axis=1)
# Out:
#           Allergies 0  Allergies 1  Allergies 2  Allergies 3  Allergies 4  \
# clusters
# 0                  82           73          108           89           84
# 1                 107           80           81           74           73
# 2                  70           87           82           76          110
# 3                  72           72           79           78           66
# 4                  66          100           70           67           62
# 5                  49           49           71           55           44
# 6                  87           72           82           79           81
# 7                 113           98          108          105          107
# 8                  90           81           87           99           80
# 9                  82           82           74           75           79
# 10                 72           52           72           83           68
# ...

# %%
for cluster, group in data_prep[cat_feat+['clusters']].groupby('clusters'):
    print(f"Cluster {cluster}:")
    # Iterate over columns (excluding the 'Cluster' column)
    for column in data_prep[cat_feat+['clusters']].columns.difference(['clusters']):
        # Count occurrences of each value in the column
        value_counts = group[column].value_counts()
        print(f"\t{column}:")
        print(value_counts)
        print()  # Add a newline for readability
    print()  # Add an additional newline to separate clusters
# Out:
# Cluster 0:
# 	Allergies:
# 2    108
# 3     89
# 4     84
# 0     82
# 1     73
# 5     67
# Name: Allergies, dtype: int64
#
# 	Fitness Goals:
# 1    503
# Name: Fitness Goals, dtype: int64
#
# 	Gender:
# 1    278
# 0    225
# Name: Gender, dtype: int64
#
# 	Work Out Level:
# 1    208
# 2    168
# 0    127
# Name: Work Out Level, dtype: int64
#
#
# Cluster 1:
# 	Allergies:
# 0    107
# 2     81
# 1     80
# 3     74
# 4     73
# 5     70
# Name: Allergies, dtype: int64
#
# 	Fitness Goals:
# 0    418
# 2     45
# 1     22
# Name: Fitness Goals, dtype: int64
#
# 	Gender:
# 1    249
# 0    236
# Name: Gender, dtype: int64
#
# 	Work Out Level:
# 1    192
# 0    157
# 2    136
# Name: Work Out Level, dtype: int64
#
#
# Cluster 2:
# 	Allergies:
# 4    110
# 5     87
# 1     87
# 2     82
# 3     76
# 0     70
# Name: Allergies, dtype: int64
#
# 	Fitness Goals:
# 1    510
# 0      2
# Name: Fitness Goals, dtype: int64
#
# 	Gender:
# 0    314
# 1    198
# Name: Gender, dtype: int64
#
# ...

# %%
# "import os 

# os.environ['HUGGINGFACEHUB_API_TOKEN'] = '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'

# from langchain import PromptTemplate ,HuggingFaceHub , LLMChain


# template = """ generate a nutrtion plan for a group(cluster) of people that has this data 


#  """

# prompt = PromptTemplate(template = template , input_variables=["question"])

# llm_chain = LLMChain(

#     llm=HuggingFaceHub(repo_id="google/flan-t5-large",model_kwargs={
#            "temperature":0,
#            "max_length":64
    
#     }),
#     prompt=prompt 

     


# )

# question = "what is the best shoe brand ?"

# print(llm_chain.run(question))"
